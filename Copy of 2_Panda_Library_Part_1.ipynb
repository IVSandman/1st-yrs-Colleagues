# %% [markdown]
# <img height="45px" src="https://avatars3.githubusercontent.com/u/20337240?s=460&v=4" align="left" hspace="10px" vspace="0px">
#
# # **Pandas Library**
# <h2> for Data Science and Machine Learning</h2>
#
# Student Name: ................................
# ID.............................
# Section............
#
# ------------------------------------------------------------------------

# %% [markdown]
# ## **1 The Python Data Analysis Library: Pandas**
#
# *  **Pandas** is an open source Python library for highly specialized data analysis.
# *  Use to the **statistical** purposes of analysis and **decision making**.
# *  This library was designed and developed primarily by **Wes McKinney** starting in 2008.
# *  In 2012, **Sien Chang**, one of his colleagues, was added to the development.
# *  A specific library to analyze data that provides, **in the simplest possible way**:
#   -   Data processing
#   -   Data extraction
#   -   Data manipulation
# *  Manage data with features similar to those designed for **SQL** relational
# databases and **Excel** spreadsheets.
#
#
# [Wes McKinney](https://en.wikipedia.org/wiki/Wes_McKinney)

# %% [markdown]
# ## **2 Introduction to pandas Data Structores**
#
# *  **series** --> the data structure designed to accommodate a
# sequence of **one-dimensional data**
#  is an open source Python library for highly specialized data analysis.
# *  **dataframe** --> is designed to contain cases with **several dimensions**.

# %% [markdown]
# **Import the pandas library.**
# *   The general practice for importing the pandas module is as follows:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### **2.1 The Series**
#
# *   Its internal structure is simple (as shown in Figure) and is composed of two arrays associated with each other
#
#     -  The main array holds the data (**value**)
#     -  Label --> called the **index**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **2.1.1 Declaring a Series**
#
# *   the **Series()** constructor and pass as an argument an array containing the values to be included in it.
#
#     -  The main array holds the data (**value**)
#     -  Label --> called the **index**

# %%
s = pd.Series([x,x,x,x])
s

# %% [markdown]
# *    In this case it will be necessary, during the constructor call, to include the index option and assign an array of strings containing the labels.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
s = pd.Series([12,-4,7,9], index=["a","b","c","d"])

# %% [markdown]
# *   You can call the two attributes of the series as follows: **index** and **values**.

# %%
s.values        # if you want to call "values"
# Out:
# array([12, -4,  7,  9])

# %%
s.index             # if you want to call "index"
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %% [markdown]
# #### **2.1.2 Selecting the Internal Elements**
#
# *   Can select individual elements as ordinary numpy arrays, specifying the key.

# %%
s[2]                #Select element at index 2
# Out:
# 7

# %% [markdown]
# *   Can specify the label corresponding to the position of the index

# %%
s['b']              #Select element by label 'b'
# Out:
# -4

# %% [markdown]
# *   Can use the corresponding labels, but specify the list of labels in an
# array.

# %%
s[[1,2]]        #Select element by the the list of labels (b and c) in an array.
# Out:
# b   -4
# c    7
# dtype: int64

# %% [markdown]
# #### **2.1.3 Assigning Values to the Elements**
#
# *   How to assign new values to them.
# *   You can **select the value by index or by label**.

# %%
s

# %%
s[1] = 0        #Assign value 0 at index 1
s
# Out:
# a    12
# b     0
# c     7
# d     9
# dtype: int64

# %%
s["b"] = 1       #Assign value 1 at index b
s
# Out:
# a    12
# b     1
# c     7
# d     9
# dtype: int64

# %% [markdown]
# #### **2.1.4 Defining a Series from NumPy Arrays**
#
# *   You can define a new series starting with NumPy arrays or with an existing series.

# %%
import numpy as np

arr = np.array([1,2,3,4])                       # Create array [1,2,3,4]
s3 = pd.Series(arr)
s3
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s4 = pd.Series(s)
s4

# %% [markdown]
# *    Keep in mind that the values contained in the NumPy array or in the
# original series are not copied, but are **passed by reference**.

# %%
arr

# %%
s3
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
arr[2] = -2
arr

# %%
s3

# %% [markdown]
# #### **2.1.5 Filtering Values**
#
# *   Many operations that are applicable to NumPy arrays are extended to the series.
# *   One of these is **filtering values** contained in the data structure
# through conditions.

# %% [markdown]
# *   **For example**, if you need to know which elements in the series (s3) are greater than 0,

# %%
s3[x>x]

# %% [markdown]
# #### **2.1.6 Operations and Mathematical Functions**
#
# *   You can simply write the arithmetic expression for the operators..

# %%
s/2
# Out:
# a    6.0
# b    0.5
# c    3.5
# d    4.5
# dtype: float64

# %% [markdown]
# *   With **NumPy mathematical functions**, you must specify the function
# referenced with **np** and the instance of the series passed as an argument.

# %%
np.sin(s)
# Out:
# a   -0.536573
# b    0.841471
# c    0.656987
# d    0.412118
# dtype: float64

# %%
np.exp(s)
# Out:
# a    162754.791419
# b         2.718282
# c      1096.633158
# d      8103.083928
# dtype: float64

# %% [markdown]
# #### **2.1.7 Evaluating Vales**
#
# *   you can declare a series in which there are many duplicate values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
serd = pd.Series([1,0,2,1,2,3],index=["white","white","blue","green","green","yellow"])                    #Create the series
serd
# Out:
# white     1
# white     0
# blue      2
# green     1
# green     2
# yellow    3
# dtype: int64

# %% [markdown]
# *   To know all the values contained in the series, excluding duplicates, you can use the **unique() function**.

# %%
serd.unique()
# Out:
# array([1, 0, 2, 3])

# %% [markdown]
# *   A function that’s similar to unique() is **value_counts()**, which not only returns unique values but also calculates the occurrences within a series.

# %%
serd.value_counts()
# Out:
# 2    2
# 1    2
# 3    1
# 0    1
# dtype: int64

# %% [markdown]
# *   **isin()** evaluates the membership, that is, the given a list of values.
# *   **Boolean values that are returned** can be very useful when filtering data

# %%
serd
# Out:
# white     1
# white     0
# blue      2
# green     1
# green     2
# yellow    3
# dtype: int64

# %%
serd.isin([0,3])
# Out:
# white     False
# white      True
# blue      False
# green     False
# green     False
# yellow     True
# dtype: bool

# %%
serd[serd.isin([0,3])]

# %% [markdown]
# #### **2.1.8 Nan Vales**
#
# *   The specific value NaN (Not a Number) is used in pandas data structures to indicate the presence of **an empty field or something that’s not definable numerically.**
# *   In special cases, such as calculations of **logarithms of negative values**, or **exceptions during execution of some calculation** or function.
# *   However, pandas allows you to explicitly define **NaNs** and add them to a data structure
# *   In the array containing the values, you enter **np.NaN** wherever you want to define a missing value.

# %%
s2 = pd.Series([5,-3,np.NaN,14])
s2
# Out:
# 0     5.0
# 1    -3.0
# 2     NaN
# 3    14.0
# dtype: float64

# %% [markdown]
# *   The **isnull()** and **notnull()** functions are very useful **to identify the indexes without a value.**

# %%
s2.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
s2.notnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# dtype: bool

# %% [markdown]
# *   These functions are often placed inside filters to make a condition.

# %%
s2[s2.isnull()]

# %%
s2[s2.notnull()]

# %% [markdown]
# #### **2.1.9 Series as Dictionaries**
#
# *   You can create a series from a previously defined dict.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
mydict = {}               #Create dict

# %%
myseries = pd.Series(mydict)
myseries

# %% [markdown]
# *   The array of the **index** is filled with the **keys** while the **data** are filled with **the corresponding values**.

# %% [markdown]
# *   If there is a **mismatch**, pandas will add the **NaN** value.

# %%
colors = ['red','yellow','orange','blue','green']

# %%
myseries = pd.Series(mydict, index=colors)
myseries

# %% [markdown]
# #### **2.1.10 Operation Between Series**
#
# *   You can create a series from a previously defined dict.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
mydict2 = {'red':400,'yellow':1000,'black':700}

# %%
myseries2 = pd.Series(mydict2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
myseries + myseries2

# %% [markdown]
# *   You get a new object series in which **only the items with the same label are added.**

# %% [markdown]
# ### **2.2 The DataFrame**
#
# *   The dataframe is a tabular data structure very similar to a **spreadsheet**.
# *   The data structure is designed to extend series to multiple dimensions.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   The dataframe has **two index arrays**.
#       - The first index array, associated with the lines, has very similar functions to the index array in series.
#       - The second array contains a series of labels, each associated with a particular column.

# %% [markdown]
# #### **2.2.1 Declaring a DataFrame**
#
# *   The most common way to create a new dataframe is precisely **to pass a dict object to the DataFrame()** constructor.

# %%
data = {'color' : ["blue","green","yellow","red","white"],
        'object' : ["ball","pen","pencil","paper","mug"],
        'price' : [1.2,1.0,0.6,0.9,1.7]}
data
# Out:
# {'color': ['blue', 'green', 'yellow', 'red', 'white'],
#  'object': ['ball', 'pen', 'pencil', 'paper', 'mug'],
#  'price': [1.2, 1.0, 0.6, 0.9, 1.7]}

# %%
frame = pd.DataFrame(data, columns=['color', 'object',"price"])
frame
# Out:
#     color  object  price
# 0    blue    ball    1.2
# 1   green     pen    1.0
# 2  yellow  pencil    0.6
# 3     red   paper    0.9
# 4   white     mug    1.7

# %% [markdown]
# *   The columns will be created in the order of the sequence regardless of how they are contained in the dict object.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
frame2 = pd.DataFrame(data, columns=['object', 'price'])
frame2
# Out:
#    object  price
# 0    ball    1.2
# 1     pen    1.0
# 2  pencil    0.6
# 3   paper    0.9
# 4     mug    1.7

# %% [markdown]
# *    If you want to assign labels to the indexes of a dataframe, you have to **use the index option** and assign it an array containing the labels

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
frame2 = pd.DataFrame(data, index=[])
frame2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1692         blocks = form_blocks(arrays, names, axes)
# -> 1693         mgr = BlockManager(blocks, axes)
#    1694         mgr._consolidate_inplace()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     328             if block.shape[1:] != mgr_shape[1:]:
# --> 329                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     330         if len(self.items) != tot_items:
#
# ...

# %% [markdown]
# *   Example to generate matrix

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
frame3 = pd.DataFrame(np.arange(0,16, dtype = int).reshape(4,4),
         index=['red','blue','yellow','white'],
         columns=['ball','pen','pencil','paper'])
frame3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fd84ba4094d7> in <module>()
# ----> 1 frame3 = pd.DataFrame(np.arange(0,16, dtype = int).reshape(4,4),
#       2          index=['red','blue','yellow','white'],
#       3          columns=['ball','pen','pencil','paper'])
#       4 frame3
#
# NameError: name 'np' is not defined

# %% [markdown]
# #### **2.2.2 Selecting Elements**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   You can is specify the **columns** attribute on the instance of **the dataframe object**

# %%
frame.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d7e335fbb62f> in <module>()
# ----> 1 frame.columns
#
# NameError: name 'frame' is not defined

# %% [markdown]
# *   To get **the list of indexes**, you should specify the **index** attribute

# %%
frame.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# *   You can also get the entire set of data contained within the data structure using the **values attribute**.

# %%
frame.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-713cff706db3> in <module>()
# ----> 1 frame.values
#
# NameError: name 'frame' is not defined

# %% [markdown]
# *   If you are interested in **selecting only the contents of a column**, you can write the name of the column

# %%
frame['price']
# Out:
# 0    1.2
# 1    1.0
# 2    0.6
# 3    0.9
# 4    1.7
# Name: price, dtype: float64

# %%
frame.price
# Out:
# 0    1.2
# 1    1.0
# 2    0.6
# 3    0.9
# 4    1.7
# Name: price, dtype: float64

# %% [markdown]
# *   **For rows within a dataframe**, it is possible to use the **loc attribute** with the index value of the row

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
frame.loc[2]
# Out:
# color     yellow
# object    pencil
# price        0.6
# Name: 2, dtype: object

# %% [markdown]
# *   **To select multiple rows**, you specify an array with the sequence of rows to insert

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
frame.loc[[2,4]]
# Out:
#     color  object  price
# 2  yellow  pencil    0.6
# 4   white     mug    1.7

# %% [markdown]
# *   If you want more than one line, you must extend the selection range

# %%
frame[2:4]
# Out:
#     color  object  price
# 2  yellow  pencil    0.6
# 3     red   paper    0.9

# %% [markdown]
# *   If you want to achieve is a single value within a dataframe
#     -  The name of the column
#     -  The index or the label of the row

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
frame['object'][3]
# Out:
# 'paper'

# %%
frame['price'][4]
# Out:
# 1.7

# %% [markdown]
# #### **2.2.3 Assigning Values**
# *   Within the dataframe structure
#     -  An array of indexes is specified by the **index attribute**
#     -  The name of the columns is specified with the **columns attribute**
#
# *   You can also assign a label, using the name attribute, to these two substructures to identify them.

# %%
import pandas as pd
frame.index.name = 'id'
frame.columns.name = 'item'
frame
# Out:
# item   color  object  price
# id
# 0       blue    ball    1.2
# 1      green     pen    1.0
# 2     yellow  pencil    0.6
# 3        red   paper    0.9
# 4      white     mug    1.7

# %% [markdown]
# *   For example, a very common operation is **to add a new column**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
frame['new'] = 12
frame
# Out:
# item   color  object  price  new
# id
# 0       blue    ball    1.2   12
# 1      green     pen    1.0   12
# 2     yellow  pencil    0.6   12
# 3        red   paper    0.9   12
# 4      white     mug    1.7   12

# %% [markdown]
# *   If you want to update the contents of a column, you have to use an array

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
frame['new'] = [3.0,1.3,2.2,0.8,1.1]
frame
# Out:
# item   color  object  price  new
# id
# 0       blue    ball    1.2  3.0
# 1      green     pen    1.0  1.3
# 2     yellow  pencil    0.6  2.2
# 3        red   paper    0.9  0.8
# 4      white     mug    1.7  1.1

# %% [markdown]
# *   The columns of a dataframe can also be created by assigning a series to one of them
# *   By specifying a series containing an increasing series of values through the
# use of **np.arange().**
#
# For Example

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
ser = pd.Series(np.arange(0,5,dtype=int))         # use np.arrage to generate serie (ser)
ser
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
frame['new'] = ser
frame
# Out:
# item   color  object  price  new
# id
# 0       blue    ball    1.2    0
# 1      green     pen    1.0    1
# 2     yellow  pencil    0.6    2
# 3        red   paper    0.9    3
# 4      white     mug    1.7    4

# %% [markdown]
# #### **2.2.4 Membership of a Value**
# *   The **isin() function** applied to the series to determine the membership of a set of values. Well, this feature is also applicable to dataframe objects.

# %%
frame
# Out:
# item   color  object  price  new
# id
# 0       blue    ball    1.2    0
# 1      green     pen    1.0    1
# 2     yellow  pencil    0.6    2
# 3        red   paper    0.9    3
# 4      white     mug    1.7    4

# %%
frame.isin([1.0,'pen'])
# Out:
# item  color  object  price    new
# id
# 0     False   False  False  False
# 1     False    True   True   True
# 2     False   False  False  False
# 3     False   False  False  False
# 4     False   False  False  False

# %% [markdown]
# *   If you pass the value returned as a condition, then you’ll get a new dataframe containing only the values that satisfy the condition

# %%
frame[frame.isin([1.0,'pen'])]
# Out:
# item color object  price  new
# id
# 0      NaN    NaN    NaN  NaN
# 1      NaN    pen    1.0  1.0
# 2      NaN    NaN    NaN  NaN
# 3      NaN    NaN    NaN  NaN
# 4      NaN    NaN    NaN  NaN

# %% [markdown]
# #### **2.2.5 Deleting a Column**
# *   If you want to delete an entire column and all its contents, use the **del command.**

# %%
frame

# %%
del frame['new']        # delete the column 'new'
frame
# Out:
# item   color  object  price
# id
# 0       blue    ball    1.2
# 1      green     pen    1.0
# 2     yellow  pencil    0.6
# 3        red   paper    0.9
# 4      white     mug    1.7

# %% [markdown]
# #### **2.2.6 DataFrame from Nested dict**
# *   A very common data structure used in Python is a nested dict, as follows

# %%
nestdict = { 'red': { 2012: 22, 2013: 33 },
             'white': { 2011: 13, 2012: 22, 2013: 16},
             'blue': {2011: 17, 2012: 27, 2013: 18}}
nestdict
# Out:
# {'blue': {2011: 17, 2012: 27, 2013: 18},
#  'red': {2012: 22, 2013: 33},
#  'white': {2011: 13, 2012: 22, 2013: 16}}

# %%
frame2 = pd.DataFrame(nestdict)
frame2
# Out:
#        red  white  blue
# 2012  22.0     22    27
# 2013  33.0     16    18
# 2011   NaN     13    17

# %% [markdown]
# #### **2.2.7 Transposition of a Dataframe**
# *   That is, **columns become rows and rows become columns*
# *   You can get the **transposition of the dataframe** by adding the **T attribute** to its application.

# %%
frame2
# Out:
#        red  white  blue
# 2012  22.0     22    27
# 2013  33.0     16    18
# 2011   NaN     13    17

# %%
frame2.T
# Out:
#        2012  2013  2011
# red    22.0  33.0   NaN
# white  22.0  16.0  13.0
# blue   27.0  18.0  17.0

# %% [markdown]
# ### **2.3 The Index Objects**
#
# *   The Index objects are responsible for the labels on the axes and other metadata as the name of the axes.
# *   Each Index object has a number of methods and properties that are useful when you need to know the values they contain

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ser = pd.Series([5,0,3,8,4], index = ['red','blue','yellow','white','green'])
ser.index
# Out:
# Index(['red', 'blue', 'yellow', 'white', 'green'], dtype='object')

# %% [markdown]
# #### **2.3.1 Methods on Index**
# *   Some specific methods for indexes available to get some information about
# indexes from a data structure.
# *   For example, **idmin()** and **idmax()** are two functions that return

# %%
ser.idxmin()
# Out:
# 'blue'

# %%
ser.idxmax()
# Out:
# 'white'

# %% [markdown]
# #### **2.3.2 Index with Duplicate Labels**
# *   You have met all cases in which indexes within a single data structure have **a unique label**.
# *   Define by way of example, **a series with some duplicate labels**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
serd = pd.Series(np.arange(0,6, dtype = int), index = ["white", "white", "blue","green","green","yellow"])
serd
# Out:
# white     0
# white     1
# blue      2
# green     3
# green     4
# yellow    5
# dtype: int64

# %% [markdown]
# *   if there are more values in correspondence of the same label, you will get a series in place of a single element.

# %%
serd['white']
# Out:
# white    0
# white    1
# dtype: int64

# %%
serd['green']
# Out:
# green    3
# green    4
# dtype: int64

# %% [markdown]
# *   **is_unique** attribute will tell you if there are indexes with duplicate labels inside the structure data **(both series and dataframe)**.

# %%
serd.index.is_unique
# Out:
# False

# %%
frame
# Out:
# item   color  object  price
# id
# 0       blue    ball    1.2
# 1      green     pen    1.0
# 2     yellow  pencil    0.6
# 3        red   paper    0.9
# 4      white     mug    1.7

# %%
frame.index.is_unique
# Out:
# True

# %% [markdown]
# ## **3 Other Functionalities on Indexes**
#
# *  This section analyzes in detail a number of basic features that take advantage of this mechanism.
#     -  **Reindexing**
#     -  **Dropping**
#     -  **Alignment**

# %% [markdown]
# ### **3.1 Reindexing**
#
# *   It is possible to obtain a **new data structure from an existing one** where
# indexing rules can be defined again.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ser = pd.Series([2,5,7,4],index = ['one','two','three','four'])
ser
# Out:
# one      2
# two      5
# three    7
# four     4
# dtype: int64

# %% [markdown]
# *   To reindex this series, pandas provides you with the **reindex()** function.
# *   This function creates a new series object with the values of the previous series rearranged according to the new sequence of labels.

# %%
ser.reindex(['three','four','five','one'])
# Out:
# three    7.0
# four     4.0
# five     NaN
# one      2.0
# dtype: float64

# %% [markdown]
# *   To better understand the functioning of this mode of automatic reindexing, define the following series.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ser3 = pd.Series([1,5,6,3], index = [0,3,5,6])
ser3
# Out:
# 0    1
# 3    5
# 5    6
# 6    3
# dtype: int64

# %% [markdown]
# *   In this example, the index column is not a perfect sequence of numbers; in fact **there are some missing values (1, 2, and 4)**
# *   To achieve this, you will use reindexing with the method option set to **ffill**.

# %%
ser3
# Out:
# 0    1
# 3    5
# 5    6
# 6    3
# dtype: int64

# %%
ser3.reindex(np.arange(0,7), method='ffill')
# Out:
# 0    1
# 1    1
# 2    1
# 3    5
# 4    5
# 5    6
# 6    3
# dtype: int64

# %% [markdown]
# *   If you want this index value **to be assigned during the interpolation**, you have to use the **bfill** method.

# %%
ser3
# Out:
# 0    1
# 3    5
# 5    6
# 6    3
# dtype: int64

# %%
ser3.reindex(range(7),method='bfill')
# Out:
# 0    1
# 1    5
# 2    5
# 3    5
# 4    6
# 5    6
# 6    3
# dtype: int64

# %% [markdown]
# *   You can have a rearrangement not only for indexes (rows), but also with regard to the columns, or even both.

# %%
frame
# Out:
# item   color  object  price
# id
# 0       blue    ball    1.2
# 1      green     pen    1.0
# 2     yellow  pencil    0.6
# 3        red   paper    0.9
# 4      white     mug    1.7

# %%
frame.reindex(range(5), method='ffill',columns=['colors','price','new','object'])
# Out:
# item  colors  price     new  object
# id
# 0       blue    1.2    blue    ball
# 1      green    1.0   green     pen
# 2     yellow    0.6  yellow  pencil
# 3        red    0.9     red   paper
# 4      white    1.7   white     mug

# %% [markdown]
# ### **3.2 Dropping**
#
# *   **drop()** function. This method will return a new object without the items that you want to delete.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ser = pd.Series(np.arange(0,4 , dtype = float), index=['red','blue','yellow','white'])
ser
# Out:
# red       0.0
# blue      1.0
# yellow    2.0
# white     3.0
# dtype: float64

# %% [markdown]
# *   If You want to delete the item corresponding to the label yellow.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ser.drop(['yellow'])
# Out:
# red      0.0
# blue     1.0
# white    3.0
# dtype: float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ser.drop(['blue','white'])
# Out:
# red        0.0
#  yellow    2.0
# dtype: float64

# %% [markdown]
# *   For the **dataframe instead**, the values can be deleted by referring to the labels of both axes.

# %%
frame = pd.DataFrame(np.arange(16).reshape((4,4)),
        index=['red','blue','yellow','white'], 
        columns=['ball','pen','pencil','paper'])
frame
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15

# %% [markdown]
# *   **To delete rows**, you just pass the **indexes of the rows**.

# %%
frame.drop(['blue','yellow'])
# Out:
#        ball  pen  pencil  paper
# red       0    1       2      3
# white    12   13      14     15

# %% [markdown]
# *   **To delete columns**, you always need to specify **the indexes of the columns**, but you must specify the axis from which to delete the elements
# *   So **to refer to the column names**, you should specify **axis = 1.**

# %%
frame.drop(['pen','pencil'],axis=1)
# Out:
#         ball  paper
# red        0      3
# blue       4      7
# yellow     8     11
# white     12     15

# %% [markdown]
# ### **3.3 Arithmetic and Data Alignment**
#
# *   pandas can **align indexes** coming from two different data structures.
# *   This is especially true when **you are performing an arithmetic operation on them.**

# %%
s1 = pd.Series([3,2,5,1],['white','yellow','green','blue'])
s1
# Out:
# white     3
# yellow    2
# green     5
# blue      1
# dtype: int64

# %%
s2 = pd.Series([1,4,7,2,1],['white','yellow','black','blue','brown'])
s2
# Out:
# white     1
# yellow    4
# black     7
# blue      2
# brown     1
# dtype: int64

# %% [markdown]
# *   Now among the various arithmetic operations, consider the simple sum.

# %%
s1 + s2
# Out:
# black     NaN
# blue      3.0
# brown     NaN
# green     NaN
# white     4.0
# yellow    6.0
# dtype: float64

# %% [markdown]
# *   In the case of the dataframe, although it may appear more complex
# *   It is carried out both for the **rows** and for the **columns**

# %%
frame1 = pd.DataFrame(np.arange(16).reshape((4,4)),
... index=['red','blue','yellow','white'],
... columns=['ball','pen','pencil','paper'])
frame1
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15

# %%
frame2 = pd.DataFrame(np.arange(12).reshape((4,3)),
... index=['blue','green','white','yellow'],
... columns=['mug','pen','ball'])
frame2
# Out:
#         mug  pen  ball
# blue      0    1     2
# green     3    4     5
# white     6    7     8
# yellow    9   10    11

# %%
frame1 + frame2
# Out:
#         ball  mug  paper   pen  pencil
# blue     6.0  NaN    NaN   6.0     NaN
# green    NaN  NaN    NaN   NaN     NaN
# red      NaN  NaN    NaN   NaN     NaN
# white   20.0  NaN    NaN  20.0     NaN
# yellow  19.0  NaN    NaN  19.0     NaN

# %% [markdown]
# ## **4 Reading and Writing Data**
#
# *  In this chapter, you will see all of the tools provided by pandas for reading data stored in many types of media (such as files and databases).
# *  This chapter focuses on a series of **I/O API functions** that pandas provides to read and write data directly as dataframe objects

# %% [markdown]
# ### **4.1 I/O API Tools**
#
# *   Set of functions called I/O API. These functions are divided into two main categories: **readers** and **writers**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **4.2 CSV and Textual Files**
#
# *   Everyone has become accustomed over the years to writing and reading files in text form.
# *   The values in a row are **separated by commas**, you have the CSV (comma-separated values) format
# *   Other forms of tabular data can be **separated by spaces or tabs**
# *   pandas provides a set of functions specific for this type of file.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **4.3 Reading Data in CSV or Text Files**

# %% [markdown]
# *   The most common operation of a person approaching data analysis is to read the data contained in a **CSV file**, or at least in a **text file**
# *   Start by creating a small CSV file in the working directory, as shown in **Listing 2-1**, and save it as **ch02_01.csv**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **4.3.1. Load data from your Google Drive**
# *   **Step 1**: In your Google Drive, create a folder.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   **Step 2**: Upload your csv file to your Google Drive in the folder you just created.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   **Step 3**: In your Notebook Colab, write the following code:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# *   **Step 4**:This command will take you to a Google authentication step. You should see a screen with Google Drive File Stream wishing to access your Google account.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   **Step 5**:After accepting the conditions, **copy the verification code and paste it** in the area indicated in your Notebook Colab.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   **Step 6**: Then click on the > icon at the top left of the Colab Notebook and then click on Files. Locate the folder you created previously and locate your csv file. Right click on the file and select Copy Path.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   **Step 7**: Finally, copy the Path as shown below:

# %%
import pandas as pd
import numpy as np
path = "/content/drive/MyDrive/Colab Notebooks/Data/ch02_01.csv"
csvframe = pd.read_csv(path)
csvframe
# Out:
#    white  red  blue  green  animal
# 0      1    5     2      3     cat
# 1      2    7     8      5     dog
# 2      3    3     6      7  horse
# 3      2    2     8      3    duck
# 4      4    4     2      3   mouse

# %% [markdown]
# *   It often happens that the tabulated data **begin directly in the first line**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
path2 = "/content/drive/MyDrive/Colab Notebooks/Data/ch02_02.csv"
pd.read_csv(path2)
# Out:
#    1  5  2  3     cat
# 0  2  7  8  5     dog
# 1  3  3  6  7  horse
# 2  2  2  8  3    duck
# 3  4  4  2  3   mouse

# %% [markdown]
# *   In this case, you could make sure that it is pandas that **assigns the default names to the columns by setting the header option to None**.

# %%
pd.read_csv(path2, header = None)
# Out:
#    0  1  2  3       4
# 0  1  5  2  3     cat
# 1  2  7  8  5     dog
# 2  3  3  6  7  horse
# 3  2  2  8  3    duck
# 4  4  4  2  3   mouse

# %% [markdown]
# *   You can specify the names directly by assigning a list of labels to the names option.

# %%
pd.read_csv(path2, names=['white', 'red', 'blue', 'green', 'animal'])
# Out:
#    white  red  blue  green  animal
# 0      1    5     2      3     cat
# 1      2    7     8      5     dog
# 2      3    3     6      7  horse
# 3      2    2     8      3    duck
# 4      4    4     2      3   mouse

# %% [markdown]
# *   To better understand this possibility, create a new CSV file with two columns to be used as indexes of the hierarchy.
# *   Then, save it in the working directory as **ch02_03.csv**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
path3 = "/content/drive/MyDrive/Colab Notebooks/Data/ch02_03.csv"
pd.read_csv(path3)
# Out:
#    color status  item1  item2  item3
# 0  black     up      3      4      6
# 1  black   down      2      6      7
# 2  white     up      5      5      5
# 3  white   down      3      3      2
# 4  white   left      1      2      1
# 5    red     up      2      2      2
# 6    red   down      1      1      4

# %%
pd.read_csv(path3, index_col = ['color', 'status'])
# Out:
#               item1  item2  item3
# color status
# black up          3      4      6
#       down        2      6      7
# white up          5      5      5
#       down        3      3      2
#       left        1      2      1
# red   up          2      2      2
#       down        1      1      4

# %% [markdown]
# #### **4.3.2. Using RegExp to Parse TXT Files**
# In these cases, the **regular expressions (RegExp)** come to our aid. In fact, you can specify a regexp within the **read_table() function** using the **sep option.**

# %% [markdown]
# *  **For example**, suppose that your TXT file has values that are **separated by spaces or tabs** in an unpredictable order.
# *  **/s** stands for the space or tab character (if you want to indicate a tab, you use **/t**), while the asterisk indicates that there may be multiple characters as shown in the table

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *  Take for example an extreme case in which we have the values separated by tabs or spaces in a random order

# %% [markdown]
# Open the text file name is "ch02_04.txt"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
path4 = "/content/drive/MyDrive/Colab Notebooks/Data/ch02_04.txt"
pd.read_table(path4)
# Out:
#   white red blue green
# 0              1 5 2 3
# 1              2 7 8 5
# 2              3 3 6 7

# %%
pd.read_table(path4, sep = '\s+')
# Out:
#    white  red  blue  green
# 0      1    5     2      3
# 1      2    7     8      5
# 2      3    3     6      7

# %% [markdown]
# *   But in reality you can consider **separator characters like alphanumeric characters**, or for example, integers such as 0.
# *   In this example, **you need to extract the numeric part from a TXT file**, in which there is a sequence of characters with numerical values and the literal characters are completely fused.

# %% [markdown]
# This file name is ch02_05.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
path5 = "/content/drive/MyDrive/Colab Notebooks/Data/ch02_05.txt"
pd.read_table(path5)
# Out:
#    000END123AAA122
# 0  001END124BBB321
# 1  002END125CCC333

# %%
pd.read_table(path5, sep ='\D+', header = None )
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py:767: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_csv(**locals())
#    0    1    2
# 0  0  123  122
# 1  1  124  321
# 2  2  125  333

# %%
pd.read_table(path5, sep = "\d+", header = None)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py:767: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_csv(**locals())
#     0    1    2   3
# 0 NaN  END  AAA NaN
# 1 NaN  END  BBB NaN
# 2 NaN  END  CCC NaN

# %% [markdown]
# *   In fact you do not always want to include headers or **unnecessary comments contained in a file**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
path6 = "/content/drive/MyDrive/Colab Notebooks/Data/ch02_06.txt"
pd.read_table(path6)
# Out:
#                    ########### LOG FILE ############
# 0   This file has been generated by automatic system
# 1                        white,red,blue,green,animal
# 2  12-Feb-2015: Counting of animals inside the house
# 3                                        1,5,2,3,cat
# 4                                        2,7,8,5,dog
# 5  13-Feb-2015: Counting of animals outside the h...
# 6                                      3,3,6,7,horse
# 7                                       2,2,8,3,duck
# 8                                      4,4,2,1,mouse

# %%
#clear all the comma in the coloum
pd.read_table(path6, sep=',' ,skiprows=[0,1,3,6])
# Out:
#    white  red  blue  green animal
# 0      1    5     2      3    cat
# 1      2    7     8      5    dog
# 2      3    3     6      7  horse
# 3      2    2     8      3   duck
# 4      4    4     2      1  mouse

# %% [markdown]
# #### **4.3.3. Reading TXT Files Into Parts**
# *   When large files are processed, or when you are only interested in portions of these files, **you often need to read the file into portions (chunks).**
# *   For example, you wanted to read only a portion of the file, you can explicitly specify the number of lines on which to parse.
# *   The **nrows** and **skiprows** options, you can select
#     -  the starting line n (**n = SkipRows**)
#     -  the lines to be read after it (**nrows = i**).

# %%
pd.read_csv(path2)
# Out:
#    1  5  2  3     cat
# 0  2  7  8  5     dog
# 1  3  3  6  7  horse
# 2  2  2  8  3    duck
# 3  4  4  2  3   mouse

# %%
pd.read_csv(path2,header=None) #กุเพิ่มเองเอาให้เข้าใจ
# Out:
#    0  1  2  3       4
# 0  1  5  2  3     cat
# 1  2  7  8  5     dog
# 2  3  3  6  7  horse
# 3  2  2  8  3    duck
# 4  4  4  2  3   mouse

# %%
pd.read_csv(path2, skiprows=[2], nrows=3, header=None)
# Out:
#    0  1  2  3     4
# 0  1  5  2  3   cat
# 1  2  7  8  5   dog
# 2  2  2  8  3  duck

# %% [markdown]
# #### **4.3.4. Writing Data in CSV**
# *   For example, you might want to write the data contained in **a dataframe to a CSV file**.
# *   You will use the **to_csv() function**, which accepts as an argument the name of the file you generate

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
frame = pd.DataFrame(np.arange(0,16,dtype= 'int').reshape(4,4),
                     index = ['red','blue','yellow','white'],
                     columns = ['ball','pen', 'pencil', 'paper'])

# %%
frame
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15

# %%
#saving path7 in to Data folder
path7 = "/content/drive/MyDrive/Colab Notebooks/Data/ch02_07.csv"

# %%
frame.to_csv(path7)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   This default behavior can be changed **by setting the two options index and header to False**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
path7b = "/content/drive/MyDrive/Colab Notebooks/Data/ch02_07b.csv"

# %%
frame.to_csv(path7b, index=False, header= False)

# %% [markdown]
# *   One point to remember when writing files is that **NaN values present in a data structure are shown as empty fields in the file**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
frame3 = pd.DataFrame([[6,np.nan,np.nan,6,np.nan],
... [np.nan,np.nan,np.nan,np.nan,np.nan],
... [np.nan,np.nan,np.nan,np.nan,np.nan],
... [20,np.nan,np.nan,20.0,np.nan],
... [19,np.nan,np.nan,19.0,np.nan]
... ],
... index=['blue','green','red','white','yellow'],
columns=['ball','mug','paper','pen','pencil'])
frame3
# Out:
#         ball  mug  paper   pen  pencil
# blue     6.0  NaN    NaN   6.0     NaN
# green    NaN  NaN    NaN   NaN     NaN
# red      NaN  NaN    NaN   NaN     NaN
# white   20.0  NaN    NaN  20.0     NaN
# yellow  19.0  NaN    NaN  19.0     NaN

# %%
path8 = "/content/drive/MyDrive/Colab Notebooks/Data/ch02_08.csv"

# %%
frame3.to_csv(path8)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   However, you can replace this empty field with a value to your liking using the **na_rep** option in the **to_csv()** function.
# *   Common values may be NULL, 0, or the same NaN

# %%
path9 = "/content/drive/MyDrive/Colab Notebooks/Data/ch02_09.csv"

# %%
frame3.to_csv(path9, na_rep ='NaN')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **5 Groupby**
#
# *  A groupby operation involves some combination of splitting the object, applying a function, and combining the results.

# %%
import pandas as pd
import math

# %% [markdown]
# ### **5.1 Titanic Dataset MockUp**
# *  Create dataframe from dictionary of list

# %%
df_ex = pd.DataFrame({'Name' :['Jack','Rose','Peter','James','Gwen','Tiffany','Pete','Albert'],
                   'Class':[1,3,2,2,math.nan,2,1,1],
                   'Age'  :[20,30,math.nan,math.nan,math.nan,15,12,18],
                   'ID'   :['ID-1','ID-2','ID-3','ID-4','ID-5','ID-6','ID-7','ID-8'],
                   'Sex'  :['Male','Female','Male','Male','Female','Female', 'Male','Male']
                  })
df_ex
# Out:
#       Name  Class   Age    ID     Sex
# 0     Jack    1.0  20.0  ID-1    Male
# 1     Rose    3.0  30.0  ID-2  Female
# 2    Peter    2.0   NaN  ID-3    Male
# 3    James    2.0   NaN  ID-4    Male
# 4     Gwen    NaN   NaN  ID-5  Female
# 5  Tiffany    2.0  15.0  ID-6  Female
# 6     Pete    1.0  12.0  ID-7    Male
# 7   Albert    1.0  18.0  ID-8    Male

# %% [markdown]
# * Use **ID** to represent as **index**

# %%
df_ex.set_index('ID', inplace = True)

# %%
df_ex
# Out:
#          Name  Class   Age     Sex
# ID
# ID-1     Jack    1.0  20.0    Male
# ID-2     Rose    3.0  30.0  Female
# ID-3    Peter    2.0   NaN    Male
# ID-4    James    2.0   NaN    Male
# ID-5     Gwen    NaN   NaN  Female
# ID-6  Tiffany    2.0  15.0  Female
# ID-7     Pete    1.0  12.0    Male
# ID-8   Albert    1.0  18.0    Male

# %% [markdown]
# ### **5.2 Groupby function**
# *  **df.groupby('column name')** --> pandas groupby object

# %%
df_ex.groupby('Sex')

# %% [markdown]
# * **.mean()**
#
# **df.groupby('column name').mean()** --> pandas groupby result in mean of specific column

# %%
df_ex.groupby('Sex').mean()
# Out:
#         Class        Age
# Sex
# Female    2.5  22.500000
# Male      1.4  16.666667

# %% [markdown]
# *  **.min()**
#
# **df.groupby('column name').min()** --> pandas groupby result in min of specific column

# %%
df_ex.groupby('Sex').min()
# Out:
#           Name  Class   Age
# Sex
# Female    Gwen    2.0  15.0
# Male    Albert    1.0  12.0

# %% [markdown]
# *  **.max()**
#
# **df.groupby('column name').max()** --> pandas groupby result in max of specific column

# %%
df_ex.groupby('Sex').max()
# Out:
#            Name  Class   Age
# Sex
# Female  Tiffany    3.0  30.0
# Male      Peter    2.0  20.0

# %% [markdown]
# *  **.count()**
#
# **df.groupby('column name').count()** --> Count elements in the group

# %%
df_ex.groupby('Sex').count()
# Out:
#         Name  Class  Age
# Sex
# Female     3      2    2
# Male       5      5    3

# %% [markdown]
# *  **.std()**
#
# **df.groupby('column name').std()** --> Find standard deviation in the group

# %%
df_ex.groupby('Sex').std()
# Out:
#            Class        Age
# Sex
# Female  0.707107  10.606602
# Male    0.547723   4.163332

# %% [markdown]
# *  **.describe()**
#
# **df.groupby('column name').describe()** --> Display the statistical data sush as:
#   - count
#   - mean
#   - std
#   - Min
#   - Q1, Q2, Q3
#   - Max

# %%
df_ex.groupby("Sex").describe()
# Out:
#        Class                            ...   Age
#        count mean       std  min   25%  ...   min    25%   50%    75%   max
# Sex                                     ...
# Female   2.0  2.5  0.707107  2.0  2.25  ...  15.0  18.75  22.5  26.25  30.0
# Male     5.0  1.4  0.547723  1.0  1.00  ...  12.0  15.00  18.0  19.00  20.0
#
# [2 rows x 16 columns]

# %% [markdown]
# *   Now, **the coloumn is multi-level dataframe**. If you want to assess in the data, you have to command as follows:

# %%
df_ex.groupby('Sex').describe()['Age']
# Out:
#         count       mean        std   min    25%   50%    75%   max
# Sex
# Female    2.0  22.500000  10.606602  15.0  18.75  22.5  26.25  30.0
# Male      3.0  16.666667   4.163332  12.0  15.00  18.0  19.00  20.0

# %%
df_ex.groupby('Sex').describe()['Age']['mean']

# %% [markdown]
# ### **5.3 Titanic DataSet with Groupby**
# *  Summarize passengers and survivors of the **Titanic Dataset** through various categories.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **5.3.1. Load Data**
# *   Read data from CSV file

# %%
path_titanic = "/content/drive/MyDrive/Colab Notebooks/Data/TitanicTrain.csv"

# %%
df_titanic = pd.read_csv(path_titanic)
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df_titanic.tail()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
# set PassengerId as index
df_titanic.set_index('?????',inplace = True)
df_titanic.head()

# %% [markdown]
# #### **5.3.2. Data Cleansing Recall**
# *   Drop column Cabin

# %%
df_titanic.drop(['Cabin'], axis = 1, inplace = True)

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 1              2         1       1  ...          PC 17599  71.2833         C
# 2              3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3              4         1       1  ...            113803  53.1000         S
# 4              5         0       3  ...            373450   8.0500         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 886          887         0       2  ...            211536  13.0000         S
# 887          888         1       1  ...            112053  30.0000         S
# 888          889         0       3  ...        W./C. 6607  23.4500         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [891 rows x 11 columns]

# %% [markdown]
# *   Drop NaN on column "Embarked"

# %%
df_titanic.dropna(subset=['Embarked'], inplace = True)
df_titanic
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 1              2         1       1  ...          PC 17599  71.2833         C
# 2              3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3              4         1       1  ...            113803  53.1000         S
# 4              5         0       3  ...            373450   8.0500         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 886          887         0       2  ...            211536  13.0000         S
# 887          888         1       1  ...            112053  30.0000         S
# 888          889         0       3  ...        W./C. 6607  23.4500         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [889 rows x 11 columns]

# %% [markdown]
# * Fill age nan with mean value

# %%
df_titanic['Age'].fillna(df_titanic['Age'].mean(), inplace = True)
df_titanic
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 1              2         1       1  ...          PC 17599  71.2833         C
# 2              3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3              4         1       1  ...            113803  53.1000         S
# 4              5         0       3  ...            373450   8.0500         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 886          887         0       2  ...            211536  13.0000         S
# 887          888         1       1  ...            112053  30.0000         S
# 888          889         0       3  ...        W./C. 6607  23.4500         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [889 rows x 11 columns]

# %% [markdown]
# *  Check the blank in table

# %%
df_titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# #### **5.3.3. Groupby Column 'Sex'**
# *  Summary of survival (by Gender)
# *  Extract the dataframe of "Survived" and "Sex" from the main data

# %%
df_titanic[['Survived','Sex']].head()
# Out:
#    Survived     Sex
# 0         0    male
# 1         1  female
# 2         1  female
# 3         1  female
# 4         0    male

# %% [markdown]
# -   Count the total number of people (by Gender)

# %%
df_titanic[['Survived','Sex']].groupby('Sex').count()
# Out:
#         Survived
# Sex
# female       312
# male         577

# %%
df_titanic.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  ...  Parch  Ticket  Fare  Embarked
# Sex                                          ...
# female          312       312     312   312  ...    312     312   312       312
# male            577       577     577   577  ...    577     577   577       577
#
# [2 rows x 10 columns]

# %%
df_titanic[['Survived','Sex']].groupby('Sex').sum()
# Out:
#         Survived
# Sex
# female       231
# male         109

# %% [markdown]
# *  Number of survivors by gender (since survived = 1, death = 0) .sum that tells how many people survive.

# %% [markdown]
# *   Find the percentage of survival (by Gender)
#     -  Ex. 1, 0, 0 that is mean value = 0.33 or percent of survival = 33%

# %%
df_titanic[['Survived','Sex']].groupby('Sex').mean()
# Out:
#         Survived
# Sex
# female  0.740385
# male    0.188908

# %% [markdown]
# #### **5.3.4. Groupby Passenger class (Pclass)**
# *  Summary of survival (by Passsenger class)
#     -  **.count()** : count the people in Pclass
#     -  **.sum()** : count the people (Survived) in Pclass
#     -  **.mean()** :  percent of the people (Survived) in each class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df_titanic[['Survived','Pclass']].head(10)
# Out:
#    Survived  Pclass
# 0         0       3
# 1         1       1
# 2         1       3
# 3         1       1
# 4         0       3
# 5         0       3
# 6         0       1
# 7         0       3
# 8         1       3
# 9         1       2

# %%
# .count() : count the people in Pclass
df_titanic[['Survived','Pclass']].groupby('Pclass').count()
# Out:
#         Survived
# Pclass
# 1            214
# 2            184
# 3            491

# %%
# sum() : count the people (Survived) in Pclass
df_titanic[['Survived','Pclass']].groupby('Pclass').sum()
# Out:
#         Survived
# Pclass
# 1            134
# 2             87
# 3            119

# %%
# .mean() : percent of the people (Survived) in each class
df_titanic[['Survived','Pclass']].groupby('Pclass').mean()
# Out:
#         Survived
# Pclass
# 1       0.626168
# 2       0.472826
# 3       0.242363

# %% [markdown]
# ## **6 Merging Dataframes**
#
# *  To learn how to merge multiple dataframe with
#     - **concat** function
#     - **merge** function

# %% [markdown]
# ### **6.1 Create dataframes**
# *  First dataframe is **df_a**

# %%
raw_data = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}
df_a = pd.DataFrame(raw_data, columns = ['subject_id', 'first_name', 'last_name'])
df_a
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %% [markdown]
# *  Second dataframe is **df_b**

# %%
raw_data = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}
df_b = pd.DataFrame(raw_data, columns = ['subject_id', 'first_name', 'last_name'])
df_b
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %% [markdown]
# *  Third dataframe is **df_n**

# %%
raw_data = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}
df_n = pd.DataFrame(raw_data, columns = ['subject_id','test_id'])
df_n
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %% [markdown]
# ### **6.2 Concat Function**
# *  Concatenate pandas objects along a particular axis

# %% [markdown]
# #### **6.2.1. Concat with no axis input (axis = 0)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Join the two dataframes along rows
df_new = pd.concat([df_a, df_b],axis = 0)
df_new
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %% [markdown]
# #### **6.2.2. Concat with axis = 1**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Join the two dataframes along columns
pd.concat([df_a, df_b], axis=1)
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %% [markdown]
# ### **6.3 Merge Function**
# *  Merge DataFrame objects by performing a database-style join operation

# %% [markdown]
# #### **6.3.1. Merge with on**
# *  **on :**
# *  Column or index level names to join on. These must be found in both DataFrames.
# *  If on is None and not merging on indexes then this defaults to the intersection of the columns in both DataFrames.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Merge two dataframes along the subject_id value
pd.merge(df_a, df_b, on='subject_id')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %% [markdown]
# #### **6.3.2. Merge with left_on, right_on**
# * **left_on**   : Column or index level names to join on in the left DataFrame
# * **right_on** : Column or index level names to join on in the right DataFrame

# %%
# Merge two dataframes with both the left and right dataframes using the subject_id key
pd.merge(df_a, df_b, left_on='subject_id', right_on='subject_id')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %% [markdown]
# #### **6.3.3. Merge with outer join**
# * **how**: outer
# * **outer**: use union of keys from both frames, similar to a SQL full outer join

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Merge with outer join
pd.merge(df_a, df_b, on='subject_id', how='outer')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# #### **6.3.4. Merge with inner join**
# * **how**: inner
# * **inner**: use intersection of keys from both frames

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Merge with inner join
pd.merge(df_a, df_b, on='subject_id', how='inner')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %% [markdown]
# #### **6.3.5. Merge with right join**
# * **how**: right
# * **right**: use only keys from right frame

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Merge with right join
pd.merge(df_a, df_b, on='subject_id', how='right')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black
# 2          6          NaN         NaN         Bran     Balwner
# 3          7          NaN         NaN        Bryce       Brice
# 4          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# #### **6.3.6. Merge with left join**
# * **how**: left
# * **left**: use only keys from left frame

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Merge with left join
pd.merge(df_a, df_b, on='subject_id', how='left')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
